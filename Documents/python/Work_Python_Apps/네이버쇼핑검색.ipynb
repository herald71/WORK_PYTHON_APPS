# %%
import os
import requests
import json
import datetime
import pandas as pd

def search_naver_shopping(query, display):
    # 환경 변수에서 네이버 API 클라이언트 ID와 시크릿 가져오기
    client_id = os.getenv('NAVER_CLIENT_ID')  # 네이버 API 클라이언트 ID
    client_secret = os.getenv('NAVER_CLIENT_SECRET')  # 네이버 API 클라이언트 시크릿
    url = f'https://openapi.naver.com/v1/search/shop.json?query={query}&display={display}'
    headers = {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # HTTP 오류가 발생하면 예외를 발생시킴

        data = response.json()
        if 'items' in data:
            return data['items']
        else:
            print('응답에 "items" 키가 없습니다.')
            return []
    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP 오류 발생: {http_err}')
    except requests.exceptions.ConnectionError as conn_err:
        print(f'연결 오류 발생: {conn_err}')
    except requests.exceptions.Timeout as timeout_err:
        print(f'타임아웃 오류 발생: {timeout_err}')
    except requests.exceptions.RequestException as req_err:
        print(f'요청 오류 발생: {req_err}')
    except json.JSONDecodeError as json_err:
        print(f'JSON 디코딩 오류 발생: {json_err}')
    except Exception as err:
        print(f'예상치 못한 오류 발생: {err}')

    return []

def save_results_to_file(items, filename):
    today_date = datetime.datetime.now().strftime("%Y-%m-%d")
    full_filename = f"{filename}_{today_date}.xlsx"
    
    try:
        # 순번 추가 및 가격을 숫자값으로 변환
        for i, item in enumerate(items, start=1):
            item['순번'] = i
            item['lprice'] = int(item['lprice']) if item['lprice'] else 0
            item['hprice'] = int(item['hprice']) if item['hprice'] else 0
        
        # 데이터프레임 생성
        df = pd.DataFrame(items)
        
        # 열 순서를 변경하여 순번을 첫 번째 열로 이동
        cols = ['순번'] + [col for col in df.columns if col != '순번']
        df = df[cols]
        
        # 엑셀 파일로 저장
        df.to_excel(full_filename, index=False)
        
        print(f"검색 결과가 파일 '{full_filename}'에 저장되었습니다.")
    except IOError as io_err:
        print(f'파일 쓰기 오류 발생: {io_err}')
    except Exception as err:
        print(f'예상치 못한 오류 발생: {err}')

def print_results(items):
    for item in items:
        print(f"순번: {item['순번']}")
        print(f"상품명: {item['title']}")
        print(f"상품 링크: {item['link']}")
        print(f"상품 이미지 링크: {item['image']}")
        print(f"최저가: {item['lprice']} 원")
        print(f"최고가: {item['hprice']} 원")
        print(f"쇼핑몰 이름: {item['mallName']}")
        print(f"상품 ID: {item['productId']}")
        print(f"상품 유형: {item['productType']}")
        print(f"브랜드명: {item['brand']}")
        print(f"제조사: {item['maker']}")
        print(f"카테고리1: {item['category1']}")
        print(f"카테고리2: {item['category2']}")
        print(f"카테고리3: {item['category3']}")
        print(f"카테고리4: {item['category4']}")
        print('-' * 50)

if __name__ == '__main__':
    query = input('검색어를 입력하세요: ')
    display = int(input('검색 결과의 개수를 입력하세요 (1-100): '))
    filename = input('저장할 파일명을 입력하세요: ')
    items = search_naver_shopping(query, display)
    if items:
        for i, item in enumerate(items, start=1):
            item['순번'] = i
        print_results(items)
        save_results_to_file(items, filename)
# Out:
# 검색어를 입력하세요: 메탈실
# 검색 결과의 개수를 입력하세요 (1-100): 100
# 저장할 파일명을 입력하세요: 메탈실
# 순번: 1
# 상품명: <b>메탈실</b> 500g 실버 콘사 실버 가방뜨기
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87648495694
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8764849/87648495694.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 코얀
# 상품 ID: 87648495694
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 2
# 상품명: (뜨개 실) 코코스백팩 실 <b>메탈실</b> 실버 화이트실버 오로라 메탈블랙
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=86570417763
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8657041/86570417763.jpg
# 최저가: 6000 원
# 최고가:  원
# 쇼핑몰 이름: 코코스뜨개
# 상품 ID: 86570417763
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 3
# 상품명: 허니비 트윙클 실버 메탈릭 골드 <b>메탈실</b>/은사 금사/ 메탈사/허니비실/반짝이 합사실/광택실 특수실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=84565090825
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8456509/84565090825.jpg
# 최저가: 4500 원
# 최고가:  원
# 쇼핑몰 이름: 니팅쭈루의 다락방
# 상품 ID: 84565090825
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 4
# 상품명: 다이아메탈릭 메탈사 실버실 뜨개 반짝이실 글리터실 실버얀 은색실 은사 <b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87877953213
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8787795/87877953213.jpg
# 최저가: 13000 원
# 최고가:  원
# 쇼핑몰 이름: 오르다공방
# 상품 ID: 87877953213
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 5
# 상품명: 다이아메탈릭(10+1) 뜨개실 실버실 메탈릭사 200g 소품실 실버네트백 <b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=86471778514
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8647177/86471778514.jpg
# 최저가: 13000 원
# 최고가:  원
# 쇼핑몰 이름: 니트러브
# 상품 ID: 86471778514
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 6
# 상품명: 메탈릭콘사 지관 제외 500g 메탈콘 대용량실 <b>메탈실</b> 금실 은실 오로라실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=82988292350
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8298829/82988292350.jpg
# 최저가: 28000 원
# 최고가:  원
# 쇼핑몰 이름: 스위니트
# 상품 ID: 82988292350
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 7
# 상품명: <b>메탈실</b> 1kg 실버 콘사 실버 가방뜨기
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87789223400
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8778922/87789223400.2.jpg
# 최저가: 40000 원
# 최고가:  원
# 쇼핑몰 이름: 코얀
# 상품 ID: 87789223400
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 8
# 상품명: 메탈릭얀 <b>메탈실</b> 호일실 실버실 콘사 500g
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87671632356
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8767163/87671632356.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 뜨개.로로
# 상품 ID: 87671632356
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 9
# 상품명: <b>메탈실</b> 대용량 500g 콘사 가방실 소품실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87670191656
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8767019/87670191656.2.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 아꾹뜨개
# 상품 ID: 87670191656
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 10
# 상품명: 뜨개랑실 가방실 소품실 금사 은사 메탈릭 <b>메탈실</b> 브라이트
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=86308402006
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8630840/86308402006.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 뜨개랑실
# 상품 ID: 86308402006
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 11
# 상품명: <b>메탈실</b> 200g 실버실 가방뜨기 콘사 <b>메탈실</b> 은사 반짝이실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87907632175
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8790763/87907632175.1.jpg
# 최저가: 11900 원
# 최고가:  원
# 쇼핑몰 이름: 핑크조아
# 상품 ID: 87907632175
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 12
# 상품명: 메탈릭얀 new<b>메탈실</b> 리얼실버 80g
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87912202812
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8791220/87912202812.jpg
# 최저가: 7500 원
# 최고가:  원
# 쇼핑몰 이름: 뜨개.로로
# 상품 ID: 87912202812
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 13
# 상품명: 메탈릭얀 <b>메탈실</b> 호일실 실버실 50g
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87671617294
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_
<b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87825678975
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8782567/87825678975.jpg
# 최저가: 6000 원
# 최고가:  원
# 쇼핑몰 이름: 니트채널
# 상품 ID: 87825678975
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 43
# 상품명: 더울 털실 뜨개 가방실 모자실 소품실 <b>메탈실</b> 브라이트
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=39326488854
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3932648/39326488854.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 위메프
# 상품 ID: 39326488854
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 44
# 상품명: 뜨개몰 브라이트 뜨개 털실 뜨개실 가방실 소품실 <b>메탈실</b>  111.검정  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=43464995629
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4346499/43464995629.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 43464995629
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 45
# 상품명: (팩)허니비 라이크퍼 like Fur <b>메탈실</b> 네프실 코바늘 대바늘 뜨개실 소품실 허니비실 겨울실 안티필링실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87111749603
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8711174/87111749603.1.jpg
# 최저가: 38000 원
# 최고가:  원
# 쇼핑몰 이름: 니팅쭈루의 다락방
# 상품 ID: 87111749603
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 46
# 상품명: [뜨개실] <b>메탈실</b> 100g 실버실 가방뜨기 반짝이실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87930061353
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8793006/87930061353.jpg
# 최저가: 5000 원
# 최고가:  원
# 쇼핑몰 이름: 애시드손뜨개
# 상품 ID: 87930061353
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 47
# 상품명: 스팽글 뜨개실, <b>메탈실</b>, 메탈가방실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87772900914
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8777290/87772900914.1.jpg
# 최저가: 19000 원
# 최고가:  원
# 쇼핑몰 이름: 냥이 공방장
# 상품 ID: 87772900914
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 48
# 상품명: 뜨개몰 브라이트 뜨개 털실 뜨개실 가방실 소품실 <b>메탈실</b>  112.연두  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=43464888030
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4346488/43464888030.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 43464888030
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 49
# 상품명: 뜨개랑실 가방실 소품실 레이스실 <b>메탈실</b> 금사 은사 카멜리아
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=86307062086
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8630706/86307062086.jpg
# 최저가: 2500 원
# 최고가:  원
# 쇼핑몰 이름: 뜨개랑실
# 상품 ID: 86307062086
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 50
# 상품명: <b>메탈실</b>(1볼) 실버 블랙 대용량 200g 코바늘가방 <b>메탈실</b>버백 반짝이가방 뜨개실
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87929572790
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8792957/87929572790.jpg
# 최저가: 13000 원
# 최고가:  원
# 쇼핑몰 이름: 할로니팅
# 상품 ID: 87929572790
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 51
# 상품명: 더울 목도리 뜨개 털실 가방실 <b>메탈실</b> 브라이트  109.빨강  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=39927258272
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3992725/39927258272.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 39927258272
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 52
# 상품명: 더울 목도리 뜨개 털실 가방실 <b>메탈실</b> 브라이트  111.검정  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=39918646077
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3991864/39918646077.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 39918646077
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 53
# 상품명: 더울 목도리 뜨개 털실 가방실 <b>메탈실</b> 브라이트  107무궁화
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=29133685594
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_2913368/29133685594.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 29133685594
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 54
# 상품명: 메탈릭얀 500g 실버 콘사 <b>메탈실</b> 반짝이실  1개  01 실버
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=48062327511
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4806232/48062327511.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 48062327511
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 55
# 상품명: 메탈릭얀 500g 실버 콘사 <b>메탈실</b> 반짝이실  1개  03 블랙
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=48062006109
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4806200/48062006109.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 48062006109
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 56
# 상품명: 메탈릭얀 500g 실버 콘사 <b>메탈실</b> 반짝이실  1개  04 골드
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=48062212192
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4806221/48062212192.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 48062212192
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 57
# 상품명: 메탈릭얀 500g 실버 콘사 <b>메탈실</b> 반짝이실  1개  02 레인보우
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=48062142800
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4806214/48062142800.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 48062142800
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 58
# 상품명: 뜨개몰 맨하탄 뜨개 털실 뜨개실 겨울실 모자실 목도리실 <b>메탈실</b>  903진회색
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=44198612044
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4419861/44198612044.jpg
# 최저가: 6000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 44198612044
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 59
# 상품명: 뜨개몰 브라이트 뜨개 털실 뜨개실 가방실 소품실 <b>메탈실</b>  104.오렌지  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=39890683623
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3989068/39890683623.jpg
# 최저가: 4000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 39890683623
# 상품 유형: 2
# 브랜드명: 남성모사
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 60
# 상품명: 뜨개몰 맨하탄 뜨개 털실 뜨개실 겨울실 모자실 목도리실 <b>메탈실</b>  912갈색
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=44222627525
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4422262/44222627525.jpg
# 최저가: 6000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 44222627525
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질실
# --------------------------------------------------
# 순번: 61
# 상품명: 뜨개몰 브라이트 뜨개 털실 뜨개실 가방실 소품실 <b>메탈실</
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3319605/33196059214.20220629184621.jpg
# 최저가: 22800 원
# 최고가:  원
# 쇼핑몰 이름: 네이버
# 상품 ID: 33196059214
# 상품 유형: 1
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 패키지
# --------------------------------------------------
# 순번: 92
# 상품명: [패키지] 비즈네트백 / 뜨개패키지 / 코바늘가방 / <b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=84424180821
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8442418/84424180821.jpg
# 최저가: 28000 원
# 최고가:  원
# 쇼핑몰 이름: 보니따손뜨개
# 상품 ID: 84424180821
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 패키지
# --------------------------------------------------
# 순번: 93
# 상품명: 애시드 손뜨개 코바늘 DIY 비즈네트백 패키지 코바늘 가방 <b>메탈실</b> 블랙펄
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=39947625979
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_3994762/39947625979.20230510173224.jpg
# 최저가: 26500 원
# 최고가:  원
# 쇼핑몰 이름: 네이버
# 상품 ID: 39947625979
# 상품 유형: 1
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 패키지
# --------------------------------------------------
# 순번: 94
# 상품명: 메탈릭얀 50g 가방 실버실 블링블링 <b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87840546491
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8784054/87840546491.jpg
# 최저가: 5000 원
# 최고가:  원
# 쇼핑몰 이름: 유나뜨개
# 상품 ID: 87840546491
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 패키지
# --------------------------------------------------
# 순번: 95
# 상품명: 울클럽 하말라야 일디즈 25g 스팽글실 <b>메탈실</b> 반짝이 코바늘 대바늘 뜨개실 58111 1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=44040069478
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4404006/44040069478.20231116074805.jpg
# 최저가: 8900 원
# 최고가:  원
# 쇼핑몰 이름: 네이버
# 상품 ID: 44040069478
# 상품 유형: 1
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질바늘
# --------------------------------------------------
# 순번: 96
# 상품명: 메탈릭얀 500g 가방 실버실 블링블링 <b>메탈실</b>
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87840689740
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8784068/87840689740.jpg
# 최저가: 25000 원
# 최고가:  원
# 쇼핑몰 이름: 유나뜨개
# 상품 ID: 87840689740
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 패키지
# --------------------------------------------------
# 순번: 97
# 상품명: 더울 털실 뜨개 목도리실 <b>메탈실</b> 마트료시카럭스
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=19530502714
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_1953050/19530502714.jpg
# 최저가: 18000 원
# 최고가:  원
# 쇼핑몰 이름: 위메프
# 상품 ID: 19530502714
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4: 뜨개질바늘
# --------------------------------------------------
# 순번: 98
# 상품명: [슬로우플로우] 블링실 250g Bling [반짝임이 매력적인 굵은 <b>메탈실</b>]  10 카키브라운  1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=42243310233
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_4224331/42243310233.jpg
# 최저가: 20000 원
# 최고가:  원
# 쇼핑몰 이름: 쿠팡
# 상품 ID: 42243310233
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 뜨개질
# 카테고리4:
# --------------------------------------------------
# 순번: 99
# 상품명: 메탈릭 코드사 4합 490g <b>메탈실</b> 실버실 뜨개실 가방실 레인보우오로라
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=87444210608
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_8744421/87444210608.2.jpg
# 최저가: 8000 원
# 최고가:  원
# 쇼핑몰 이름: MS스타샵
# 상품 ID: 87444210608
# 상품 유형: 2
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 자수
# 카테고리4: 실/바늘
# --------------------------------------------------
# 순번: 100
# 상품명: 소잉홀릭 메탈릭사 10컬러 - 금실 은실 <b>메탈실</b> 6 910 1개
# 상품 링크: https://search.shopping.naver.com/gate.nhn?id=22848697447
# 상품 이미지 링크: https://shopping-phinf.pstatic.net/main_2284869/22848697447.20200513154313.jpg
# 최저가: 8500 원
# 최고가:  원
# 쇼핑몰 이름: 네이버
# 상품 ID: 22848697447
# 상품 유형: 1
# 브랜드명:
# 제조사:
# 카테고리1: 가구/인테리어
# 카테고리2: 수예
# 카테고리3: 자수
# 카테고리4: 실/바늘
# --------------------------------------------------
# 검색 결과가 파일 '메탈실_2024-05-30.xlsx'에 저장되었습니다.
